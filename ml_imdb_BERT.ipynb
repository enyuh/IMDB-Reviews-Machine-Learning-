# %%
# %matplotlib inline

## Install some stuff you likely don't have
# !pip3 -q install --upgrade pip
# !pip3 -q install pandas_path
# !pip3 -q install fasttext
# !pip3 -q install umap-learn[plot]
# !pip3 -q install ipywidgets --user
# !pip3 -q install transformers

import json
import logging
from pathlib import Path
import random
import tarfile
import tempfile
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pandas_path  # Path style access for pandas
from tqdm import tqdm

import torch                    
import torchvision
import fasttext

import os

from PIL import Image
import umap
import umap.plot
# Out:
#      |████████████████████████████████| 1.5MB 8.3MB/s
#      |████████████████████████████████| 68 kB 4.2 MB/s
#   Building wheel for fasttext (setup.py) ... done
#      |████████████████████████████████| 1.6 MB 7.8 MB/s
#      |████████████████████████████████| 15.8 MB 84 kB/s
#      |████████████████████████████████| 76 kB 6.0 MB/s
#      |████████████████████████████████| 103 kB 65.3 MB/s
#      |████████████████████████████████| 675 kB 70.5 MB/s
#      |████████████████████████████████| 675 kB 60.2 MB/s
#      |████████████████████████████████| 672 kB 71.5 MB/s
#      |████████████████████████████████| 671 kB 70.7 MB/s
#      |████████████████████████████████| 669 kB 75.4 MB/s
#      |████████████████████████████████| 656 kB 37.7 MB/s
#   Building wheel for datashape (setup.py) ... done
#      |████████████████████████████████| 1.9 MB 8.9 MB/s
#      |████████████████████████████████| 3.2 MB 54.5 MB/s
#      |████████████████████████████████| 883 kB 51.2 MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from tqdm import tqdm_notebook as tqdm_n
import tqdm
import transformers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys, os
sys.path.insert(0,'/content/drive/My Drive/')

# %%
# !unzip /content/drive/MyDrive/imdb_data/aclImdb.zip
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: aclImdb/train/pos/9260_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9260_7.txt
#   inflating: aclImdb/train/pos/1599_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1599_7.txt
#   inflating: aclImdb/train/pos/2174_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2174_8.txt
#   inflating: aclImdb/train/pos/2309_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2309_9.txt
#   inflating: aclImdb/train/pos/12034_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12034_10.txt
#   inflating: aclImdb/train/pos/11703_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11703_9.txt
#   inflating: aclImdb/train/pos/5619_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5619_9.txt
#   inflating: aclImdb/train/pos/2928_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2928_10.txt
#   inflating: aclImdb/train/pos/7096_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7096_10.txt
#   inflating: aclImdb/train/pos/793_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._793_9.txt
#   inflating: aclImdb/train/pos/7693_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7693_9.txt
#   inflating: aclImdb/train/pos/8293_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8293_8.txt
#   inflating: aclImdb/train/pos/29_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._29_10.txt
#   inflating: aclImdb/train/pos/8642_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8642_8.txt
#   inflating: aclImdb/train/pos/3187_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3187_7.txt
#   inflating: aclImdb/train/pos/4497_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4497_7.txt
#   inflating: aclImdb/train/pos/2659_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2659_8.txt
#   inflating: aclImdb/train/pos/10119_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10119_7.txt
#   inflating: aclImdb/train/pos/1665_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1665_7.txt
#   inflating: aclImdb/train/pos/11078_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11078_10.txt
#   inflating: aclImdb/train/pos/4840_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4840_7.txt
#   inflating: aclImdb/train/pos/11729_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11729_10.txt
#   inflating: aclImdb/train/pos/7570_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7570_10.txt
#   inflating: aclImdb/train/pos/6047_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6047_10.txt
#   inflating: aclImdb/train/pos/9292_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9292_10.txt
#   inflating: aclImdb/train/pos/5798_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5798_8.txt
#   inflating: aclImdb/train/pos/639_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._639_10.txt
#   inflating: aclImdb/train/pos/8508_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8508_7.txt
#   inflating: aclImdb/train/pos/10216_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10216_8.txt
#   inflating: aclImdb/train/pos/9125_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9125_10.txt
#   inflating: aclImdb/train/pos/4798_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4798_8.txt
#   inflating: aclImdb/train/pos/3461_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3461_9.txt
#   inflating: aclImdb/train/pos/6207_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6207_9.txt
#   inflating: aclImdb/train/pos/1864_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1864_10.txt
#   inflating: aclImdb/train/pos/12125_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12125_8.txt
#   inflating: aclImdb/train/pos/7321_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7321_10.txt
#   inflating: aclImdb/train/pos/7375_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7375_7.txt
#   inflating: aclImdb/train/pos/7470_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7470_10.txt
#   inflating: aclImdb/train/pos/5840_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5840_7.txt
#   inflating: aclImdb/train/pos/11629_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11629_10.txt
#   inflating: aclImdb/train/pos/951_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._951_10.txt
#   inflating: aclImdb/train/pos/8922_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8922_7.txt
#   inflating: aclImdb/train/pos/11535_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11535_7.txt
#   inflating: aclImdb/train/pos/4518_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4518_9.txt
#   inflating: aclImdb/train/pos/1597_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1597_8.txt
#   inflating: aclImdb/train/pos/12149_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12149_10.txt
#   inflating: aclImdb/train/pos/5627_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5627_10.txt
#   inflating: aclImdb/train/pos/10890_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10890_9.txt
#   inflating: aclImdb/train/pos/4720_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4720_8.txt
#   inflating: aclImdb/train/pos/5176_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5176_10.txt
#   inflating: aclImdb/train/pos/3230_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3230_8.txt
#   inflating: aclImdb/train/pos/6759_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6759_7.txt
#   inflating: aclImdb/train/pos/10535_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10535_7.txt
#   inflating: aclImdb/train/pos/6388_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6388_7.txt
#   inflating: aclImdb/train/pos/12049_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12049_10.txt
#   inflating: aclImdb/train/pos/3939_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3939_7.txt
#   inflating: aclImdb/train/pos/4541_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4541_10.txt
#   inflating: aclImdb/train/pos/5076_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5076_10.txt
#   inflating: aclImdb/train/pos/2955_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2955_10.txt
#   inflating: aclImdb/train/pos/187_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._187_8.txt
#   inflating: aclImdb/train/pos/9709_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9709_10.txt
#   inflating: aclImdb/train/pos/10785_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10785_10.txt
#   inflating: aclImdb/train/pos/9609_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9609_7.txt
#   inflating: aclImdb/train/pos/8543_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8543_8.txt
#   inflating: aclImdb/train/pos/800_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._800_9.txt
#   inflating: aclImdb/train/pos/6031_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6031_7.txt
#   inflating: aclImdb/train/pos/3657_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3657_7.txt
#   inflating: aclImdb/train/pos/7592_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7592_9.txt
#   inflating: aclImdb/train/pos/54_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._54_10.txt
#   inflating: aclImdb/train/pos/6872_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6872_7.txt
#   inflating: aclImdb/train/pos/11005_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11005_10.txt
#   inflating: aclImdb/train/pos/8089_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8089_10.txt
#   inflating: aclImdb/train/pos/10263_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10263_10.txt
#   inflating: aclImdb/train/pos/8506_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8506_8.txt
#   inflating: aclImdb/train/pos/3612_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3612_7.txt
#   inflating: aclImdb/train/pos/6074_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6074_7.txt
#   inflating: aclImdb/train/pos/2640_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2640_10.txt
#   inflating: aclImdb/train/pos/8994_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8994_8.txt
#   inflating: aclImdb/train/pos/10117_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10117_8.txt
#   inflating: aclImdb/train/pos/115_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._115_10.txt
#   inflating: aclImdb/train/pos/3791_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3791_10.txt
#   inflating: aclImdb/train/pos/5347_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5347_7.txt
#   inflating: aclImdb/train/pos/9158_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9158_10.txt
#   inflating: aclImdb/train/pos/12059_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12059_9.txt
#   inflating: aclImdb/train/pos/7074_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7074_7.txt
#   inflating: aclImdb/train/pos/174_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._174_7.txt
#   inflating: aclImdb/train/pos/3558_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3558_8.txt
#   inflating: aclImdb/train/pos/8189_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8189_10.txt
#   inflating: aclImdb/train/pos/10432_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10432_10.txt
#   inflating: aclImdb/train/pos/11105_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11105_10.txt
#   inflating: aclImdb/train/pos/5932_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5932_10.txt
#   inflating: aclImdb/train/pos/3189_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3189_8.txt
#   inflating: aclImdb/train/pos/6106_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6106_9.txt
#   inflating: aclImdb/train/pos/9506_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9506_8.txt
#   inflating: aclImdb/train/pos/11043_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11043_7.txt
#   inflating: aclImdb/train/pos/6165_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6165_8.txt
#   inflating: aclImdb/train/pos/2449_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2449_7.txt
#   inflating: aclImdb/train/pos/11996_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11996_10.txt
#   inflating: aclImdb/train/pos/1475_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1475_8.txt
#   inflating: aclImdb/train/pos/11492_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11492_7.txt
#   inflating: aclImdb/train/pos/11006_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11006_7.txt
#   inflating: aclImdb/train/pos/5447_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5447_10.txt
#   inflating: aclImdb/train/pos/12329_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12329_10.txt
#   inflating: aclImdb/train/pos/8083_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8083_7.txt
#   inflating: aclImdb/train/pos/6963_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6963_8.txt
#   inflating: aclImdb/train/pos/4256_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4256_8.txt
#   inflating: aclImdb/train/pos/12202_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12202_9.txt
#   inflating: aclImdb/train/pos/4687_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4687_8.txt
#   inflating: aclImdb/train/pos/10937_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10937_9.txt
#   inflating: aclImdb/train/pos/986_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._986_10.txt
#   inflating: aclImdb/train/pos/8452_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8452_7.txt
#   inflating: aclImdb/train/pos/1608_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1608_9.txt
#   inflating: aclImdb/train/pos/11131_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11131_9.txt
#   inflating: aclImdb/train/pos/4596_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4596_10.txt
#   inflating: aclImdb/train/pos/5213_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5213_8.txt
#   inflating: aclImdb/train/pos/3953_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3953_10.txt
#   inflating: aclImdb/train/pos/218_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._218_9.txt
#   inflating: aclImdb/train/pos/10006_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10006_7.txt
#   inflating: aclImdb/train/pos/4070_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4070_10.txt
#   inflating: aclImdb/train/pos/10847_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10847_10.txt
#   inflating: aclImdb/train/pos/275_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._275_10.txt
#   inflating: aclImdb/train/pos/524_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._524_10.txt
#   inflating: aclImdb/train/pos/3321_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3321_7.txt
#   inflating: aclImdb/train/pos/2682_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2682_9.txt
#   inflating: aclImdb/train/pos/7435_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7435_9.txt
#   inflating: aclImdb/train/pos/9238_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9238_10.txt
#   inflating: aclImdb/train/pos/11783_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11783_10.txt
#   inflating: aclImdb/train/pos/1486_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1486_7.txt
#   inflating: aclImdb/train/pos/11659_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11659_9.txt
#   inflating: aclImdb/train/pos/4674_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4674_7.txt
#   inflating: aclImdb/train/pos/8248_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8248_9.txt
#   inflating: aclImdb/train/pos/2420_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2420_10.txt
#   inflating: aclImdb/train/pos/83_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._83_10.txt
#   inflating: aclImdb/train/pos/11424_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11424_8.txt
#   inflating: aclImdb/train/pos/10752_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10752_10.txt
#   inflating: aclImdb/train/pos/11265_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11265_10.txt
#   inflating: aclImdb/train/pos/8070_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8070_8.txt
#   inflating: aclImdb/train/pos/2216_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2216_9.txt
#   inflating: aclImdb/train/pos/5706_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5706_9.txt
#   inflating: aclImdb/train/pos/7299_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7299_8.txt
#   inflating: aclImdb/train/pos/9469_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9469_10.txt
#   inflating: aclImdb/train/pos/9876_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9876_8.txt
#   inflating: aclImdb/train/pos/4392_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4392_9.txt
#   inflating: aclImdb/train/pos/2797_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2797_10.txt
#   inflating: aclImdb/train/pos/7990_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7990_7.txt
#   inflating: aclImdb/train/pos/6299_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6299_8.txt
#   inflating: aclImdb/train/pos/9833_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9833_8.txt
#   inflating: aclImdb/train/pos/5674_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5674_7.txt
#   inflating: aclImdb/train/pos/9248_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9248_9.txt
#   inflating: aclImdb/train/pos/2520_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2520_10.txt
#   inflating: aclImdb/train/pos/693_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._693_10.txt
#   inflating: aclImdb/train/pos/3746_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3746_10.txt
#   inflating: aclImdb/train/pos/7502_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7502_7.txt
#   inflating: aclImdb/train/pos/10230_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10230_9.txt
#   inflating: aclImdb/train/pos/2399_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2399_7.txt
#   inflating: aclImdb/train/pos/3402_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3402_8.txt
#   inflating: aclImdb/train/pos/4951_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4951_8.txt
#   inflating: aclImdb/train/pos/12354_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12354_10.txt
#   inflating: aclImdb/train/pos/9419_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9419_8.txt
#   inflating: aclImdb/train/pos/12405_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12405_10.txt
#   inflating: aclImdb/train/pos/7905_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7905_10.txt
#   inflating: aclImdb/train/pos/4157_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4157_8.txt
#   inflating: aclImdb/train/pos/8382_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8382_7.txt
#   inflating: aclImdb/train/pos/7264_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7264_8.txt
#   inflating: aclImdb/train/pos/10342_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10342_7.txt
#   inflating: aclImdb/train/pos/8867_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8867_10.txt
#   inflating: aclImdb/train/pos/1340_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1340_10.txt
#   inflating: aclImdb/train/pos/7221_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7221_8.txt
#   inflating: aclImdb/train/pos/5914_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5914_8.txt
#   inflating: aclImdb/train/pos/12254_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12254_10.txt
#   inflating: aclImdb/train/pos/5586_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5586_8.txt
#   inflating: aclImdb/train/pos/7805_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7805_10.txt
#   inflating: aclImdb/train/pos/8334_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8334_8.txt
#   inflating: aclImdb/train/pos/9514_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9514_10.txt
#   inflating: aclImdb/train/pos/11760_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11760_8.txt
#   inflating: aclImdb/train/pos/3863_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3863_7.txt
#   inflating: aclImdb/train/pos/4530_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4530_7.txt
#   inflating: aclImdb/train/pos/7771_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7771_9.txt
#   inflating: aclImdb/train/pos/9878_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9878_7.txt
#   inflating: aclImdb/train/pos/4849_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4849_10.txt
#   inflating: aclImdb/train/pos/10760_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10760_8.txt
#   inflating: aclImdb/train/pos/5998_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5998_10.txt
#   inflating: aclImdb/train/pos/2020_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2020_7.txt
#   inflating: aclImdb/train/pos/10498_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10498_10.txt
#   inflating: aclImdb/train/pos/1224_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1224_9.txt
#   inflating: aclImdb/train/pos/4442_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4442_9.txt
#   inflating: aclImdb/train/pos/459_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._459_10.txt
#   inflating: aclImdb/train/pos/3152_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3152_9.txt
#   inflating: aclImdb/train/pos/8394_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8394_10.txt
#   inflating: aclImdb/train/pos/6476_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6476_10.txt
#   inflating: aclImdb/train/pos/2065_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2065_7.txt
#   inflating: aclImdb/train/pos/6549_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6549_8.txt
#   inflating: aclImdb/train/pos/9149_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9149_9.txt
#   inflating: aclImdb/train/pos/11449_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11449_10.txt
#   inflating: aclImdb/train/pos/6327_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6327_10.txt
#   inflating: aclImdb/train/pos/3954_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3954_9.txt
#   inflating: aclImdb/train/pos/12082_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12082_8.txt
#   inflating: aclImdb/train/pos/3109_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3109_10.txt
#   inflating: aclImdb/train/pos/2727_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2727_9.txt
#   inflating: aclImdb/train/pos/3658_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3658_10.txt
#   inflating: aclImdb/train/pos/3655_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3655_7.txt
#   inflating: aclImdb/train/pos/12129_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12129_7.txt
#   inflating: aclImdb/train/pos/490_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._490_9.txt
#   inflating: aclImdb/train/pos/9091_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9091_10.txt
#   inflating: aclImdb/train/pos/7773_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7773_10.txt
#   inflating: aclImdb/train/pos/2762_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2762_9.txt
#   inflating: aclImdb/train/pos/8504_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8504_8.txt
#   inflating: aclImdb/train/pos/7295_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7295_10.txt
#   inflating: aclImdb/train/pos/4300_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4300_7.txt
#   inflating: aclImdb/train/pos/8996_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8996_8.txt
#   inflating: aclImdb/train/pos/7033_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7033_7.txt
#   inflating: aclImdb/train/pos/1669_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1669_8.txt
#   inflating: aclImdb/train/pos/6590_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6590_9.txt
#   inflating: aclImdb/train/pos/1080_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1080_9.txt
#   inflating: aclImdb/train/pos/9779_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9779_9.txt
#   inflating: aclImdb/train/pos/9191_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9191_10.txt
#   inflating: aclImdb/train/pos/6141_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6141_9.txt
#   inflating: aclImdb/train/pos/9541_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9541_8.txt
#   inflating: aclImdb/train/pos/8140_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8140_10.txt
#   inflating: aclImdb/train/pos/9326_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9326_10.txt
#   inflating: aclImdb/train/pos/176_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._176_7.txt
#   inflating: aclImdb/train/pos/12226_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12226_8.txt
#   inflating: aclImdb/train/pos/10959_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10959_10.txt
#   inflating: aclImdb/train/pos/1339_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1339_9.txt
#   inflating: aclImdb/train/pos/5308_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5308_10.txt
#   inflating: aclImdb/train/pos/1572_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1572_10.txt
#   inflating: aclImdb/train/pos/1101_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1101_8.txt
#   inflating: aclImdb/train/pos/11537_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11537_7.txt
#   inflating: aclImdb/train/pos/9011_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9011_9.txt
#   inflating: aclImdb/train/pos/12180_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12180_10.txt
#   inflating: aclImdb/train/pos/8126_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8126_7.txt
#   inflating: aclImdb/train/pos/6085_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6085_8.txt
#   inflating: aclImdb/train/pos/4488_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4488_10.txt
#   inflating: aclImdb/train/pos/1144_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1144_8.txt
#   inflating: aclImdb/train/pos/10638_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10638_8.txt
#   inflating: aclImdb/train/pos/4722_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4722_8.txt
#   inflating: aclImdb/train/pos/5468_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5468_7.txt
#   inflating: aclImdb/train/pos/9054_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9054_9.txt
#   inflating: aclImdb/train/pos/8852_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8852_9.txt
#   inflating: aclImdb/train/pos/5767_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5767_8.txt
#   inflating: aclImdb/train/pos/11094_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11094_9.txt
#   inflating: aclImdb/train/pos/898_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._898_10.txt
#   inflating: aclImdb/train/pos/1323_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1323_10.txt
#   inflating: aclImdb/train/pos/12237_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12237_10.txt
#   inflating: aclImdb/train/pos/7866_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7866_10.txt
#   inflating: aclImdb/train/pos/9920_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9920_7.txt
#   inflating: aclImdb/train/pos/5722_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5722_8.txt
#   inflating: aclImdb/train/pos/11892_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11892_9.txt
#   inflating: aclImdb/train/pos/4468_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4468_7.txt
#   inflating: aclImdb/train/pos/8804_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8804_10.txt
#   inflating: aclImdb/train/pos/791_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._791_9.txt
#   inflating: aclImdb/train/pos/7691_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7691_9.txt
#   inflating: aclImdb/train/pos/8291_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8291_8.txt
#   inflating: aclImdb/train/pos/2426_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2426_9.txt
#   inflating: aclImdb/train/pos/11206_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11206_10.txt
#   inflating: aclImdb/train/pos/1667_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1667_7.txt
#   inflating: aclImdb/train/pos/547_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._547_10.txt
#   inflating: aclImdb/train/pos/11680_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11680_8.txt
#   inflating: aclImdb/train/pos/5886_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5886_10.txt
#   inflating: aclImdb/train/pos/10586_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10586_10.txt
#   inflating: aclImdb/train/pos/5173_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5173_9.txt
#   inflating: aclImdb/train/pos/11457_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11457_10.txt
#   inflating: aclImdb/train/pos/2543_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2543_10.txt
#   inflating: aclImdb/train/pos/12162_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12162_8.txt
#   inflating: aclImdb/train/pos/6078_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6078_8.txt
#   inflating: aclImdb/train/pos/6691_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6691_9.txt
#   inflating: aclImdb/train/pos/7332_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7332_7.txt
#   inflating: aclImdb/train/pos/2554_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2554_7.txt
#   inflating: aclImdb/train/pos/2212_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2212_10.txt
#   inflating: aclImdb/train/pos/10680_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10680_8.txt
#   inflating: aclImdb/train/pos/5986_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5986_10.txt
#   inflating: aclImdb/train/pos/2983_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2983_7.txt
#   inflating: aclImdb/train/pos/316_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._316_10.txt
#   inflating: aclImdb/train/pos/12127_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12127_8.txt
#   inflating: aclImdb/train/pos/5001_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5001_7.txt
#   inflating: aclImdb/train/pos/447_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._447_10.txt
#   inflating: aclImdb/train/pos/3592_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3592_10.txt
#   inflating: aclImdb/train/pos/10924_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10924_10.txt
#   inflating: aclImdb/train/pos/5424_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5424_10.txt
#   inflating: aclImdb/train/pos/4466_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4466_8.txt
#   inflating: aclImdb/train/pos/4642_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4642_10.txt
#   inflating: aclImdb/train/pos/6528_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6528_9.txt
#   inflating: aclImdb/train/pos/3830_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3830_10.txt
#   inflating: aclImdb/train/pos/8979_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8979_10.txt
#   inflating: aclImdb/train/pos/4423_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4423_8.txt
#   inflating: aclImdb/train/pos/8227_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8227_7.txt
#   inflating: aclImdb/train/pos/12191_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12191_7.txt
#   inflating: aclImdb/train/pos/11744_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11744_9.txt
#   inflating: aclImdb/train/pos/7710_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7710_8.txt
#   inflating: aclImdb/train/pos/2176_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2176_8.txt
#   inflating: aclImdb/train/pos/10824_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10824_10.txt
#   inflating: aclImdb/train/pos/5466_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5466_8.txt
#   inflating: aclImdb/train/pos/5275_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5275_10.txt
#   inflating: aclImdb/train/pos/8784_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8784_9.txt
#   inflating: aclImdb/train/pos/11701_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11701_9.txt
#   inflating: aclImdb/train/pos/4769_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4769_7.txt
#   inflating: aclImdb/train/pos/5793_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5793_10.txt
#   inflating: aclImdb/train/pos/7238_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7238_9.txt
#   inflating: aclImdb/train/pos/5555_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5555_10.txt
#   inflating: aclImdb/train/pos/4062_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4062_10.txt
#   inflating: aclImdb/train/pos/1198_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1198_10.txt
#   inflating: aclImdb/train/pos/8094_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8094_9.txt
#   inflating: aclImdb/train/pos/2990_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2990_10.txt
#   inflating: aclImdb/train/pos/4584_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4584_10.txt
#   inflating: aclImdb/train/pos/5304_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5304_10.txt
#   inflating: aclImdb/train/pos/1510_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1510_8.txt
#   inflating: aclImdb/train/pos/4162_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4162_10.txt
#   inflating: aclImdb/train/pos/8572_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8572_7.txt
#   inflating: aclImdb/train/pos/6238_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6238_9.txt
#   inflating: aclImdb/train/pos/9638_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9638_8.txt
#   inflating: aclImdb/train/pos/8908_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8908_10.txt
#   inflating: aclImdb/train/pos/11984_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11984_10.txt
#   inflating: aclImdb/train/pos/10229_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10229_8.txt
#   inflating: aclImdb/train/pos/1555_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1555_8.txt
#   inflating: aclImdb/train/pos/3623_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3623_8.txt
#   inflating: aclImdb/train/pos/10011_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10011_9.txt
#   inflating: aclImdb/train/pos/12367_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12367_9.txt
#   inflating: aclImdb/train/pos/11426_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11426_10.txt
#   inflating: aclImdb/train/pos/6348_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6348_10.txt
#   inflating: aclImdb/train/pos/5385_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5385_7.txt
#   inflating: aclImdb/train/pos/10996_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10996_8.txt
#   inflating: aclImdb/train/pos/6419_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6419_10.txt
#   inflating: aclImdb/train/pos/9150_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9150_8.txt
#   inflating: aclImdb/train/pos/2263_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2263_10.txt
#   inflating: aclImdb/train/pos/6181_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6181_9.txt
#   inflating: aclImdb/train/pos/1491_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1491_9.txt
#   inflating: aclImdb/train/pos/6768_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6768_8.txt
#   inflating: aclImdb/train/pos/7399_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7399_10.txt
#   inflating: aclImdb/train/pos/436_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._436_10.txt
#   inflating: aclImdb/train/pos/367_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._367_10.txt
#   inflating: aclImdb/train/pos/3654_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3654_10.txt
#   inflating: aclImdb/train/pos/6422_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6422_7.txt
#   inflating: aclImdb/train/pos/11504_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11504_8.txt
#   inflating: aclImdb/train/pos/7768_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7768_8.txt
#   inflating: aclImdb/train/pos/11526_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11526_10.txt
#   inflating: aclImdb/train/pos/11277_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11277_10.txt
#   inflating: aclImdb/train/pos/7550_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7550_9.txt
#   inflating: aclImdb/train/pos/536_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._536_10.txt
#   inflating: aclImdb/train/pos/6467_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6467_7.txt
#   inflating: aclImdb/train/pos/2908_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2908_8.txt
#   inflating: aclImdb/train/pos/2685_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2685_10.txt
#   inflating: aclImdb/train/pos/8956_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8956_8.txt
#   inflating: aclImdb/train/pos/1352_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1352_10.txt
#   inflating: aclImdb/train/pos/8539_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8539_8.txt
#   inflating: aclImdb/train/pos/7817_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7817_10.txt
#   inflating: aclImdb/train/pos/9673_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9673_7.txt
#   inflating: aclImdb/train/pos/10828_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10828_10.txt
#   inflating: aclImdb/train/pos/2522_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2522_8.txt
#   inflating: aclImdb/train/pos/12114_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12114_7.txt
#   inflating: aclImdb/train/pos/3668_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3668_7.txt
#   inflating: aclImdb/train/pos/9636_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9636_7.txt
#   inflating: aclImdb/train/pos/12023_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12023_9.txt
#   inflating: aclImdb/train/pos/12417_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12417_10.txt
#   inflating: aclImdb/train/pos/10355_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10355_9.txt
#   inflating: aclImdb/train/pos/1429_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1429_9.txt
#   inflating: aclImdb/train/pos/5428_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5428_10.txt
#   inflating: aclImdb/train/pos/8673_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8673_7.txt
#   inflating: aclImdb/train/pos/12346_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12346_10.txt
#   inflating: aclImdb/train/pos/3567_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3567_8.txt
#   inflating: aclImdb/train/pos/4834_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4834_8.txt
#   inflating: aclImdb/train/pos/8975_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8975_10.txt
#   inflating: aclImdb/train/pos/10310_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10310_9.txt
#   inflating: aclImdb/train/pos/9395_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9395_9.txt
#   inflating: aclImdb/train/pos/8636_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8636_7.txt
#   inflating: aclImdb/train/pos/4871_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4871_8.txt
#   inflating: aclImdb/train/pos/3522_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3522_8.txt
#   inflating: aclImdb/train/pos/11262_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11262_7.txt
#   inflating: aclImdb/train/pos/5378_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5378_7.txt
#   inflating: aclImdb/train/pos/1790_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1790_9.txt
#   inflating: aclImdb/train/pos/5455_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5455_7.txt
#   inflating: aclImdb/train/pos/7602_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7602_10.txt
#   inflating: aclImdb/train/pos/6335_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6335_10.txt
#   inflating: aclImdb/train/pos/9680_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9680_8.txt
#   inflating: aclImdb/train/pos/2145_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2145_7.txt
#   inflating: aclImdb/train/pos/3729_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3729_10.txt
#   inflating: aclImdb/train/pos/3874_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3874_9.txt
#   inflating: aclImdb/train/pos/4527_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4527_9.txt
#   inflating: aclImdb/train/pos/5084_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5084_7.txt
#   inflating: aclImdb/train/pos/3078_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3078_10.txt
#   inflating: aclImdb/train/pos/5410_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5410_7.txt
#   inflating: aclImdb/train/pos/10640_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10640_8.txt
#   inflating: aclImdb/train/pos/7766_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7766_7.txt
#   inflating: aclImdb/train/pos/2100_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2100_7.txt
#   inflating: aclImdb/train/pos/6614_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6614_9.txt
#   inflating: aclImdb/train/pos/4562_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4562_9.txt
#   inflating: aclImdb/train/pos/9958_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9958_7.txt
#   inflating: aclImdb/train/pos/3594_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3594_7.txt
#   inflating: aclImdb/train/pos/751_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._751_9.txt
#   inflating: aclImdb/train/pos/4084_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4084_7.txt
#   inflating: aclImdb/train/pos/1233_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1233_7.txt
#   inflating: aclImdb/train/pos/7702_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7702_10.txt
#   inflating: aclImdb/train/pos/10998_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10998_7.txt
#   inflating: aclImdb/train/pos/8603_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8603_10.txt
#   inflating: aclImdb/train/pos/10699_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10699_9.txt
#   inflating: aclImdb/train/pos/8152_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8152_10.txt
#   inflating: aclImdb/train/pos/815_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._815_7.txt
#   inflating: aclImdb/train/pos/3642_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3642_9.txt
#   inflating: aclImdb/train/pos/379_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._379_10.txt
#   inflating: aclImdb/train/pos/6867_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6867_9.txt
#   inflating: aclImdb/train/pos/7661_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7661_10.txt
#   inflating: aclImdb/train/pos/11438_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11438_10.txt
#   inflating: aclImdb/train/pos/6259_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6259_8.txt
#   inflating: aclImdb/train/pos/9183_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9183_10.txt
#   inflating: aclImdb/train/pos/2775_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2775_7.txt
#   inflating: aclImdb/train/pos/7130_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7130_10.txt
#   inflating: aclImdb/train/pos/6407_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6407_10.txt
#   inflating: aclImdb/train/pos/4220_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4220_7.txt
#   inflating: aclImdb/train/pos/8703_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8703_10.txt
#   inflating: aclImdb/train/pos/2607_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2607_9.txt
#   inflating: aclImdb/train/pos/788_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._788_8.txt
#   inflating: aclImdb/train/pos/4838_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4838_10.txt
#   inflating: aclImdb/train/pos/1403_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1403_7.txt
#   inflating: aclImdb/train/pos/7761_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7761_10.txt
#   inflating: aclImdb/train/pos/7030_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7030_10.txt
#   inflating: aclImdb/train/pos/3775_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3775_7.txt
#   inflating: aclImdb/train/pos/6507_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6507_10.txt
#   inflating: aclImdb/train/pos/11035_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11035_8.txt
#   inflating: aclImdb/train/pos/359_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._359_8.txt
#   inflating: aclImdb/train/pos/4548_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4548_7.txt
#   inflating: aclImdb/train/pos/8174_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8174_9.txt
#   inflating: aclImdb/train/pos/8937_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8937_9.txt
#   inflating: aclImdb/train/pos/10083_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10083_7.txt
#   inflating: aclImdb/train/pos/4199_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4199_7.txt
#   inflating: aclImdb/train/pos/9006_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9006_7.txt
#   inflating: aclImdb/train/pos/9492_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9492_7.txt
#   inflating: aclImdb/train/pos/7531_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7531_8.txt
#   inflating: aclImdb/train/pos/1460_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1460_10.txt
#   inflating: aclImdb/train/pos/431_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._431_8.txt
#   inflating: aclImdb/train/pos/10885_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10885_7.txt
#   inflating: aclImdb/train/pos/609_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._609_9.txt
#   inflating: aclImdb/train/pos/9043_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9043_7.txt
#   inflating: aclImdb/train/pos/11565_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11565_9.txt
#   inflating: aclImdb/train/pos/2489_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2489_7.txt
#   inflating: aclImdb/train/pos/5199_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5199_7.txt
#   inflating: aclImdb/train/pos/10520_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10520_9.txt
#   inflating: aclImdb/train/pos/5548_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5548_7.txt
#   inflating: aclImdb/train/pos/3312_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3312_8.txt
#   inflating: aclImdb/train/pos/6574_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6574_8.txt
#   inflating: aclImdb/train/pos/9174_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9174_9.txt
#   inflating: aclImdb/train/pos/4602_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4602_8.txt
#   inflating: aclImdb/train/pos/11885_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11885_7.txt
#   inflating: aclImdb/train/pos/10565_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10565_9.txt
#   inflating: aclImdb/train/pos/11417_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11417_7.txt
#   inflating: aclImdb/train/pos/6531_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6531_8.txt
#   inflating: aclImdb/train/pos/9131_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9131_9.txt
#   inflating: aclImdb/train/pos/1862_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1862_8.txt
#   inflating: aclImdb/train/pos/4647_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4647_8.txt
#   inflating: aclImdb/train/pos/10149_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10149_9.txt
#   inflating: aclImdb/train/pos/786_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._786_7.txt
#   inflating: aclImdb/train/pos/9418_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9418_10.txt
#   inflating: aclImdb/train/pos/4810_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4810_9.txt
#   inflating: aclImdb/train/pos/10494_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10494_10.txt
#   inflating: aclImdb/train/pos/10371_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10371_8.txt
#   inflating: aclImdb/train/pos/5962_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5962_7.txt
#   inflating: aclImdb/train/pos/3580_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3580_10.txt
#   inflating: aclImdb/train/pos/455_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._455_10.txt
#   inflating: aclImdb/train/pos/304_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._304_10.txt
#   inflating: aclImdb/train/pos/12493_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12493_8.txt
#   inflating: aclImdb/train/pos/9760_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9760_8.txt
#   inflating: aclImdb/train/pos/10334_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10334_8.txt
#   inflating: aclImdb/train/pos/1448_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1448_8.txt
#   inflating: aclImdb/train/pos/3066_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3066_10.txt
#   inflating: aclImdb/train/pos/2192_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2192_9.txt
#   inflating: aclImdb/train/pos/10878_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10878_7.txt
#   inflating: aclImdb/train/pos/4962_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4962_7.txt
#   inflating: aclImdb/train/pos/3480_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3480_10.txt
#   inflating: aclImdb/train/pos/204_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._204_10.txt
#   inflating: aclImdb/train/pos/225_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._225_9.txt
#   inflating: aclImdb/train/pos/5810_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5810_9.txt
#   inflating: aclImdb/train/pos/7325_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7325_9.txt
#   inflating: aclImdb/train/pos/7_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7_7.txt
#   inflating: aclImdb/train/pos/9518_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9518_10.txt
#   inflating: aclImdb/train/pos/3637_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3637_10.txt
#   inflating: aclImdb/train/pos/2300_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2300_10.txt
#   inflating: aclImdb/train/pos/7158_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7158_8.txt
#   inflating: aclImdb/train/pos/7589_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7589_8.txt
#   inflating: aclImdb/train/pos/2506_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2506_9.txt
#   inflating: aclImdb/train/pos/5855_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5855_9.txt
#   inflating: aclImdb/train/pos/5991_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5991_8.txt
#   inflating: aclImdb/train/pos/11621_9.txt
# ...
#   inflating: aclImdb/train/pos/6813_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6813_10.txt
#   inflating: aclImdb/train/pos/757_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._757_8.txt
#   inflating: aclImdb/train/pos/5521_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5521_8.txt
#   inflating: aclImdb/train/pos/12407_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12407_7.txt
#   inflating: aclImdb/train/pos/1130_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1130_10.txt
#   inflating: aclImdb/train/pos/2938_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2938_10.txt
#   inflating: aclImdb/train/pos/2031_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2031_8.txt
#   inflating: aclImdb/train/pos/8257_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8257_9.txt
#   inflating: aclImdb/train/pos/1499_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1499_7.txt
#   inflating: aclImdb/train/pos/12293_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12293_10.txt
#   inflating: aclImdb/train/pos/2837_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2837_8.txt
#   inflating: aclImdb/train/pos/1030_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1030_10.txt
#   inflating: aclImdb/train/pos/2838_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2838_10.txt
#   inflating: aclImdb/train/pos/3031_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3031_8.txt
#   inflating: aclImdb/train/pos/6286_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6286_8.txt
#   inflating: aclImdb/train/pos/1796_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1796_8.txt
#   inflating: aclImdb/train/pos/3074_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3074_8.txt
#   inflating: aclImdb/train/pos/6612_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6612_8.txt
#   inflating: aclImdb/train/pos/9212_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9212_9.txt
#   inflating: aclImdb/train/pos/9971_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9971_10.txt
#   inflating: aclImdb/train/pos/1979_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1979_9.txt
#   inflating: aclImdb/train/pos/9894_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9894_8.txt
#   inflating: aclImdb/train/pos/3536_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3536_10.txt
#   inflating: aclImdb/train/pos/837_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._837_7.txt
#   inflating: aclImdb/train/pos/2750_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2750_10.txt
#   inflating: aclImdb/train/pos/1809_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1809_10.txt
#   inflating: aclImdb/train/pos/11644_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11644_10.txt
#   inflating: aclImdb/train/pos/10483_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10483_8.txt
#   inflating: aclImdb/train/pos/9406_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9406_8.txt
#   inflating: aclImdb/train/pos/11115_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11115_10.txt
#   inflating: aclImdb/train/pos/8199_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8199_10.txt
#   inflating: aclImdb/train/pos/654_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._654_10.txt
#   inflating: aclImdb/train/pos/9619_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9619_10.txt
#   inflating: aclImdb/train/pos/6800_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6800_9.txt
#   inflating: aclImdb/train/pos/4335_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4335_9.txt
#   inflating: aclImdb/train/pos/5822_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5822_10.txt
#   inflating: aclImdb/train/pos/1464_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1464_7.txt
#   inflating: aclImdb/train/pos/10318_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10318_7.txt
#   inflating: aclImdb/train/pos/2458_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2458_8.txt
#   inflating: aclImdb/train/pos/11811_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11811_8.txt
#   inflating: aclImdb/train/pos/1909_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1909_10.txt
#   inflating: aclImdb/train/pos/2650_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2650_10.txt
#   inflating: aclImdb/train/pos/3712_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3712_7.txt
#   inflating: aclImdb/train/pos/3757_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3757_7.txt
#   inflating: aclImdb/train/pos/8092_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8092_8.txt
#   inflating: aclImdb/train/pos/11851_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11851_10.txt
#   inflating: aclImdb/train/pos/4551_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4551_10.txt
#   inflating: aclImdb/train/pos/3839_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3839_7.txt
#   inflating: aclImdb/train/pos/2330_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2330_8.txt
#   inflating: aclImdb/train/pos/7556_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7556_8.txt
#   inflating: aclImdb/train/pos/11_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11_9.txt
#   inflating: aclImdb/train/pos/2945_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2945_10.txt
#   inflating: aclImdb/train/pos/7187_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7187_8.txt
#   inflating: aclImdb/train/pos/10435_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10435_7.txt
#   inflating: aclImdb/train/pos/2375_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2375_8.txt
#   inflating: aclImdb/train/pos/6288_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6288_7.txt
#   inflating: aclImdb/train/pos/841_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._841_10.txt
#   inflating: aclImdb/train/pos/9061_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9061_7.txt
#   inflating: aclImdb/train/pos/11547_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11547_9.txt
#   inflating: aclImdb/train/pos/881_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._881_8.txt
#   inflating: aclImdb/train/pos/1497_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1497_8.txt
#   inflating: aclImdb/train/pos/10502_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10502_9.txt
#   inflating: aclImdb/train/pos/5166_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5166_10.txt
#   inflating: aclImdb/train/pos/5637_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5637_10.txt
#   inflating: aclImdb/train/pos/7288_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7288_7.txt
#   inflating: aclImdb/train/pos/941_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._941_10.txt
#   inflating: aclImdb/train/pos/3894_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3894_10.txt
#   inflating: aclImdb/train/pos/10547_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10547_9.txt
#   inflating: aclImdb/train/pos/5480_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5480_10.txt
#   inflating: aclImdb/train/pos/2545_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2545_8.txt
#   inflating: aclImdb/train/pos/4785_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4785_10.txt
#   inflating: aclImdb/train/pos/5055_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5055_8.txt
#   inflating: aclImdb/train/pos/11377_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11377_9.txt
#   inflating: aclImdb/train/pos/11949_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11949_8.txt
#   inflating: aclImdb/train/pos/10691_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10691_7.txt
#   inflating: aclImdb/train/pos/1299_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1299_10.txt
#   inflating: aclImdb/train/pos/4484_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4484_8.txt
#   inflating: aclImdb/train/pos/10377_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10377_9.txt
#   inflating: aclImdb/train/pos/9723_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9723_9.txt
#   inflating: aclImdb/train/pos/4816_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4816_8.txt
#   inflating: aclImdb/train/pos/3992_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3992_8.txt
#   inflating: aclImdb/train/pos/2826_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2826_10.txt
#   inflating: aclImdb/train/pos/10949_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10949_8.txt
#   inflating: aclImdb/train/pos/6366_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6366_8.txt
#   inflating: aclImdb/train/pos/9766_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9766_9.txt
#   inflating: aclImdb/train/pos/4432_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4432_10.txt
#   inflating: aclImdb/train/pos/11240_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11240_7.txt
#   inflating: aclImdb/train/pos/601_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._601_7.txt
#   inflating: aclImdb/train/pos/637_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._637_10.txt
#   inflating: aclImdb/train/pos/5477_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5477_7.txt
#   inflating: aclImdb/train/pos/9808_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9808_9.txt
#   inflating: aclImdb/train/pos/4997_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4997_9.txt
#   inflating: aclImdb/train/pos/3015_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3015_9.txt
#   inflating: aclImdb/train/pos/480_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._480_10.txt
#   inflating: aclImdb/train/pos/2062_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2062_10.txt
#   inflating: aclImdb/train/pos/3268_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3268_8.txt
#   inflating: aclImdb/train/pos/11528_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11528_7.txt
#   inflating: aclImdb/train/pos/5432_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5432_7.txt
#   inflating: aclImdb/train/pos/2122_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2122_7.txt
#   inflating: aclImdb/train/pos/3204_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3204_10.txt
#   inflating: aclImdb/train/pos/2733_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2733_10.txt
#   inflating: aclImdb/train/pos/3050_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3050_9.txt
#   inflating: aclImdb/train/pos/10441_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10441_10.txt
#   inflating: aclImdb/train/pos/11590_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11590_10.txt
#   inflating: aclImdb/train/pos/4890_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4890_10.txt
#   inflating: aclImdb/train/pos/3924_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3924_7.txt
#   inflating: aclImdb/train/pos/4477_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4477_7.txt
#   inflating: aclImdb/train/pos/1211_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1211_7.txt
#   inflating: aclImdb/train/pos/27_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._27_10.txt
#   inflating: aclImdb/train/pos/11627_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11627_8.txt
#   inflating: aclImdb/train/pos/5997_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5997_9.txt
#   inflating: aclImdb/train/pos/8808_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8808_9.txt
#   inflating: aclImdb/train/pos/3167_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3167_7.txt
#   inflating: aclImdb/train/pos/2484_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2484_10.txt
#   inflating: aclImdb/train/pos/6718_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6718_10.txt
#   inflating: aclImdb/train/pos/10541_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10541_10.txt
#   inflating: aclImdb/train/pos/2162_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2162_10.txt
#   inflating: aclImdb/train/pos/3455_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3455_10.txt
#   inflating: aclImdb/train/pos/1254_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1254_7.txt
#   inflating: aclImdb/train/pos/3304_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3304_10.txt
#   inflating: aclImdb/train/pos/9550_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9550_7.txt
#   inflating: aclImdb/train/pos/12272_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12272_7.txt
#   inflating: aclImdb/train/pos/6368_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6368_7.txt
#   inflating: aclImdb/train/pos/2644_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2644_8.txt
#   inflating: aclImdb/train/pos/11033_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._11033_9.txt
#   inflating: aclImdb/train/pos/5129_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5129_9.txt
#   inflating: aclImdb/train/pos/12047_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12047_10.txt
#   inflating: aclImdb/train/pos/1153_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._1153_10.txt
#   inflating: aclImdb/train/pos/4354_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4354_8.txt
#   inflating: aclImdb/train/pos/6861_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6861_8.txt
#   inflating: aclImdb/train/pos/3644_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3644_8.txt
#   inflating: aclImdb/train/pos/9422_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9422_9.txt
#   inflating: aclImdb/train/pos/10076_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._10076_9.txt
#   inflating: aclImdb/train/pos/9912_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9912_10.txt
#   inflating: aclImdb/train/pos/5818_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5818_7.txt
#   inflating: aclImdb/train/pos/5178_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5178_10.txt
#   inflating: aclImdb/train/pos/12147_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._12147_10.txt
#   inflating: aclImdb/train/pos/5629_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5629_10.txt
#   inflating: aclImdb/train/pos/3439_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3439_9.txt
#   inflating: aclImdb/train/pos/7892_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7892_7.txt
#   inflating: aclImdb/train/pos/992_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._992_7.txt
#   inflating: aclImdb/train/pos/9156_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9156_10.txt
#   inflating: aclImdb/train/pos/6383_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6383_10.txt
#   inflating: aclImdb/train/pos/9974_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9974_8.txt
#   inflating: aclImdb/train/pos/4641_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4641_9.txt
#   inflating: aclImdb/train/pos/7445_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7445_7.txt
#   inflating: aclImdb/train/pos/4479_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4479_8.txt
#   inflating: aclImdb/train/pos/6665_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6665_10.txt
#   inflating: aclImdb/train/pos/5733_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._5733_7.txt
#   inflating: aclImdb/train/pos/7352_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._7352_10.txt
#   inflating: aclImdb/train/pos/3169_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3169_8.txt
#   inflating: aclImdb/train/pos/4290_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._4290_9.txt
#   inflating: aclImdb/train/pos/3266_7.txt
#   inflating: __MACOSX/aclImdb/train/pos/._3266_7.txt
#   inflating: aclImdb/train/pos/8561_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8561_10.txt
#   inflating: aclImdb/train/pos/8230_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._8230_10.txt
#   inflating: aclImdb/train/pos/9707_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._9707_10.txt
#   inflating: aclImdb/train/pos/35_8.txt
#   inflating: __MACOSX/aclImdb/train/pos/._35_8.txt
#   inflating: aclImdb/train/pos/6034_10.txt
#   inflating: __MACOSX/aclImdb/train/pos/._6034_10.txt
#   inflating: aclImdb/train/pos/2780_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._2780_9.txt
#   inflating: aclImdb/train/pos/437_9.txt
#   inflating: __MACOSX/aclImdb/train/pos/._437_9.txt

# %%
import re
   
def preprocess_text(sen):
    # Removing html tags
    sentence = remove_tags(sen)
    # Remove punctuations and numbers
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)
    # Single character removal
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence)
    # Removing multiple spaces
    sentence = re.sub(r'\s+', ' ', sentence)
    return sentence
TAG_RE = re.compile(r'<[^>]+>')
def remove_tags(text):
    return TAG_RE.sub('', text)

# %%
def path_to_dataframe(path):
  path1 = path+'neg/'
  all_files = os.listdir(path1)
  all_files.sort(key=lambda x:int(x[:-4]))
  dictionary_list = []
  for file in all_files:
    with open(os.path.join(path1, file),'r',encoding="utf8") as f:
      text = preprocess_text(f.read())
      dictionary_list.append({'text':text, 'label':0})
  path2 = path+'pos/'
  all_files = os.listdir(path2)
  all_files.sort(key=lambda x:int(x[:-4]))
  for file in all_files:
    with open(os.path.join(path2, file),'r',encoding="utf8") as f:
      text = preprocess_text(f.read())
      dictionary_list.append({'text':text, 'label':1})
  random.shuffle(dictionary_list)
  df = pd.DataFrame.from_dict(dictionary_list)
  return df

# %%
train_path = '/content/aclImdb/train/'
test_path = '/content/aclImdb/test/'

original_set = path_to_dataframe(train_path)
test_set = path_to_dataframe(test_path)

print(original_set.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    25000 non-null  object
#  1   label   25000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 390.8+ KB
# None

# %%
dev_set = original_set[20000:25000]
train_set = original_set[:20000]

# Overview of data
print(train_set.info())
print(dev_set.info())
dev_set.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    20000 non-null  object
#  1   label   20000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 312.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 20000 to 24999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5000 non-null   object
#  1   label   5000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 78.3+ KB
# None
#                                                     text  label
# 20000  Return of the Jedi is certainly the most actio...      1
# 20001  I may be getting ahead of myself here but alth...      1
# 20002  This is essentially variation on House Of Wax ...      1
# 20003  Like said its hidden surprise It well written ...      1
# 20004  When small glob of space age silly putty lands...      0

# %%
import transformers
from transformers import BertModel, BertTokenizer, AdamW, get_linear_schedule_with_warmup
import torch

import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from collections import defaultdict
from textwrap import wrap

from torch import nn, optim
from torch.utils.data import Dataset, DataLoader

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]

sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    20000 non-null  object
#  1   label   20000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 312.6+ KB

# %%
sns.countplot(train_set.label)
plt.xlabel('imdb labels')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'imdb labels')

# %%
sns.countplot(dev_set.label)
plt.xlabel('imdb labels')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'imdb labels')

# %%
sns.countplot(test_set.label)
plt.xlabel('imdb labels')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'imdb labels')

# %%
PRE_TRAINED_MODEL_NAME = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…

# %%
token_lens = []

for txt in train_set.text:
  tokens = tokenizer.encode(txt, max_length=1500)
  token_lens.append(len(tokens))
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
sns.distplot(token_lens)
plt.xlim([0, 1500]);
plt.xlabel('Token count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Token count')

# %%
class PytorchTokenized(Dataset):

  def __init__(self, reviews, targets, tokenizer, max_len):
    self.reviews = reviews
    self.targets = targets
    self.tokenizer = tokenizer
    self.max_len = max_len

  def __len__(self):
    return len(self.reviews)

  def __getitem__(self, item):
    reviews = str(self.reviews[item])
    target = self.targets[item]
    encoding = self.tokenizer.encode_plus(
      reviews,
      add_special_tokens=True,
      max_length=self.max_len,
      return_token_type_ids=False,
      pad_to_max_length=True,
      return_attention_mask=True,
      return_tensors='pt',
    )
    return {
      'reviews': reviews,
      'input_ids': encoding['input_ids'].flatten(),
      'attention_mask': encoding['attention_mask'].flatten(),
      'targets': torch.tensor(target, dtype=torch.long)
    }

# %%
def create_data_loader(df, tokenizer, max_len, batch_size):
  ds = PytorchTokenized(
    reviews=df.text.to_numpy(),
    targets=df.label.to_numpy(),
    tokenizer=tokenizer,
    max_len=max_len
  )

  return DataLoader(
    ds,
    batch_size=batch_size,
    num_workers=4
  )

# %%
BATCH_SIZE = 12
MAX_LEN = 512

train_data_loader = create_data_loader(train_set, tokenizer, MAX_LEN, BATCH_SIZE)
val_data_loader = create_data_loader(dev_set, tokenizer, MAX_LEN, BATCH_SIZE)
test_data_loader = create_data_loader(test_set, tokenizer, MAX_LEN, BATCH_SIZE)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
bert_model = BertModel.from_pretrained(PRE_TRAINED_MODEL_NAME)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…

# %%
class ReviewClassifier(nn.Module):

  def __init__(self, n_classes):
    super(ReviewClassifier, self).__init__()
    self.bert = BertModel.from_pretrained(PRE_TRAINED_MODEL_NAME)
    self.drop = nn.Dropout(p=0.3)
    self.out = nn.Linear(self.bert.config.hidden_size, n_classes)

  def forward(self, input_ids, attention_mask):
    returned = self.bert(
    input_ids=input_ids,
    attention_mask=attention_mask
    )
    pooled_output = returned["pooler_output"]
    output = self.drop(pooled_output)
    return self.out(output)

# %%
model = ReviewClassifier(2)
model = model.to(device)

# %%
EPOCHS = 10

optimizer = AdamW(model.parameters(), lr=2e-5, correct_bias=False)
total_steps = len(train_data_loader) * EPOCHS

scheduler = get_linear_schedule_with_warmup(
  optimizer,
  num_warmup_steps=0,
  num_training_steps=total_steps
)

loss_fn = nn.CrossEntropyLoss().to(device)

# %%
def train_epoch(
  model,
  data_loader,
  loss_fn,
  optimizer,
  device,
  scheduler,
  n_examples
):
  model = model.train()

  losses = []
  correct_predictions = 0

  for d in data_loader:
    input_ids = d["input_ids"].to(device)
    attention_mask = d["attention_mask"].to(device)
    targets = d["targets"].to(device)

    outputs = model(
      input_ids=input_ids,
      attention_mask=attention_mask
    )

    _, preds = torch.max(outputs, dim=1)
    loss = loss_fn(outputs, targets)

    correct_predictions += torch.sum(preds == targets)
    losses.append(loss.item())

    loss.backward()
    nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()

  return correct_predictions.double() / n_examples, np.mean(losses)

# %%
def eval_model(model, data_loader, loss_fn, device, n_examples):
  model = model.eval()

  losses = []
  correct_predictions = 0

  with torch.no_grad():
    for d in data_loader:
      input_ids = d["input_ids"].to(device)
      attention_mask = d["attention_mask"].to(device)
      targets = d["targets"].to(device)

      outputs = model(
        input_ids=input_ids,
        attention_mask=attention_mask
      )
      _, preds = torch.max(outputs, dim=1)

      loss = loss_fn(outputs, targets)

      correct_predictions += torch.sum(preds == targets)
      losses.append(loss.item())

  return correct_predictions.double() / n_examples, np.mean(losses)

# %%
# %%time

history = defaultdict(list)


for epoch in range(EPOCHS):

  print(f'Epoch {epoch + 1}/{EPOCHS}')
  print('-' * 10)

  train_acc, train_loss = train_epoch(
    model,
    train_data_loader,
    loss_fn,
    optimizer,
    device,
    scheduler,
    len(train_set)
  )

  print(f'Train loss {train_loss} accuracy {train_acc}')

  val_acc, val_loss= eval_model(
    model,
    val_data_loader,
    loss_fn,
    device,
    len(dev_set)
  )

  print(f'Val   loss {val_loss} accuracy {val_acc}')
  print()

  history['train_acc'].append(train_acc)
  history['train_loss'].append(train_loss)
  history['val_acc'].append(val_acc)
  history['val_loss'].append(val_loss)
# Out:
# Epoch 1/10
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Train loss 0.31900390138599327 accuracy 0.8807
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Val   loss 0.21890496231762946 accuracy 0.9198000000000001
#
# Epoch 2/10
# ----------
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Train loss 0.17518490604793285 accuracy 0.9533
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Val   loss 0.3393879694907705 accuracy 0.9224
#
# Epoch 3/10
# ----------
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Train loss 0.10328807874863655 accuracy 0.97685
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Val   loss 0.5104809629220551 accuracy 0.8994000000000001
#
# Epoch 4/10
# ----------
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Train loss 0.06242278592039699 accuracy 0.98765
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Val   loss 0.4467350398974797 accuracy 0.9198000000000001
#
# Epoch 5/10
# ----------
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Train loss 0.04280011208824887 accuracy 0.9923500000000001
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Val   loss 0.4739640384261458 accuracy 0.9228000000000001
#
# Epoch 6/10
# ----------
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Train loss 0.03291933029491231 accuracy 0.9941500000000001
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Val   loss 0.49317042248804294 accuracy 0.9222
#
# Epoch 7/10
# ----------
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Train loss 0.02362803722971374 accuracy 0.996
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Val   loss 0.5131369573357979 accuracy 0.9236000000000001
#
# Epoch 8/10
# ----------
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Train loss 0.016807340452455636 accuracy 0.9971500000000001
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Val   loss 0.5455589168794381 accuracy 0.923
#
# Epoch 9/10
# ----------
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Train loss 0.013250432336235326 accuracy 0.9977
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Val   loss 0.5565349964979267 accuracy 0.9254
#
# Epoch 10/10
# ----------
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Train loss 0.009223657425251861 accuracy 0.9982500000000001
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Val   loss 0.5709685921577123 accuracy 0.9242
#
# CPU times: user 3h 5min 13s, sys: 2h 58min 35s, total: 6h 3min 48s
# Wall time: 6h 5min 21s

# %%
plt.plot(history['train_acc'], label='train accuracy')
plt.plot(history['val_acc'], label='validation accuracy')

plt.title('Training history')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1]);

# %%
plt.plot(history['train_loss'], label='train loss')
plt.plot(history['val_loss'], label='validation loss')

plt.title('Training history')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

# %%
def eval_model2(model, data_loader, loss_fn, device, n_examples):
  model = model.eval()

  losses = []
  correct_predictions = 0
  predictions = np.array([])
  with torch.no_grad():
    for d in data_loader:
      input_ids = d["input_ids"].to(device)
      attention_mask = d["attention_mask"].to(device)
      targets = d["targets"].to(device)

      outputs = model(
        input_ids=input_ids,
        attention_mask=attention_mask
      )
      _, preds = torch.max(outputs, dim=1)
      
      predictions = np.append(predictions, preds.cpu().numpy())
      loss = loss_fn(outputs, targets)

      correct_predictions += torch.sum(preds == targets)
      losses.append(loss.item())

  return correct_predictions.double() / n_examples, np.mean(losses), predictions

# %%
test_acc, _, test_predictions = eval_model2(
  model,
  test_data_loader,
  loss_fn,
  device,
  len(test_set)
)

test_acc.item()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# 0.92712

# %%
print(test_predictions)
# Out:
# [0. 1. 1. ... 0. 0. 0.]

# %%
predictions_df = pd.DataFrame()
predictions_df['y_pred'] = test_predictions
predictions_df['y_truth'] = test_set['label']
predictions_df['y_pred'] = predictions_df['y_pred'].astype(int)

predictions_df.head()
# Out:
#    y_pred  y_truth
# 0       0        0
# 1       1        1
# 2       1        1
# 3       1        1
# 4       0        0

# %%
predictions_df.to_csv('predictions_bert.csv')

# %%
from google.colab import files
files.download('/content/predictions_bert.csv')

# %%
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/ml_imdb_BERT.ipynb" ./ 
# !jupyter nbconvert --to PDF "ml_imdb_BERT.ipynb"

# %%
files.download('/content/ml_imdb_BERT.ipynb')
files.download('/content/ml_imdb_BERT.pdf')

# %%
print('Done')
